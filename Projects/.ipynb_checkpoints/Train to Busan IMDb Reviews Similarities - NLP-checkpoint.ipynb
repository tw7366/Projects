# %% [markdown]
# ## Analysis of Train to Busan (2020) Reviews
#
# There are a few things I want to achieve through this analysis
#
# I would like to
# * find keywords from the reviews
# * get the average of reviews (/10)
# * find similarities between reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
import bs4 as bs
import time
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import gensim
import re
from gensim.models.doc2vec import TaggedDocument
from gensim.models.doc2vec import Doc2Vec

# %%
path = r'C:\ProgramData\chocolatey\bin\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.imdb.com/title/tt5700672/reviews?ref_=tt_ov_rt')

# on IMDb website, there aren't pages but load more buttons, so to grab the source code of all reviews, need to use selenium
while True:
    try:
        # load more until there is no more
        load_more = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'load-more-trigger'))
        )
        time.sleep(2)
        ActionChains(driver).move_to_element(load_more).click(load_more).perform()
    except:
        # store the source code of all reviews
        html = driver.page_source
        driver.quit()
        break

# %%
titles = []
ratings = []
reviews = []

# web scraping using BeautifulSoup
soup = bs.BeautifulSoup(html, 'lxml')
all_containers = soup.findAll('div', {'class':'lister-item-content'})
for container in all_containers:
    # title cannot be empty
    titles.append(container.a.text.strip())
    if container.div.span.span is None:
        ratings.append(np.nan)
    else:
        ratings.append(container.div.span.span.text)
    if container.findChildren('div')[2].div is None:
        reviews.append('None')
    else:
        reviews.append(container.findChildren('div')[2].div.text)

# %%
frame = {'Title':titles, 'Rating':ratings, 'Review':reviews}
review_df = pd.DataFrame(frame)
# pd.set_option('display.max_rows', None)
review_df.head(10)
# Out:
#                                                Title Rating  \
# 0                                     Zombie Revival      8
# 1  Unforgettable experience! One of the best zomb...      9
# 2                   As Promised. Action-Packed Film!    NaN
# 3                      The Best Zombie Movie To Date     10
# 4                          best modern zombies movie     10
# 5                       More Than Just a Zombie Film     10
# 6             The best zombie movie I have ever seen     10
# 7                                  Board this train!      8
# 8                                   Worth your time!      9
# 9           Adds a lot of spark to the zombie genre.      8
#
#                                               Review
# 0  Train to Busan was a treat. A look into Selfis...
# 1  Forget about the ordinary and immerse yourself...
# 2                                               None
# 3  This movie did what I have not seen many, if a...
# 4  Hello,We can argue whether a zombies should be...
# 5  This new Korean film "Train to Busan" is certa...
# 6  The best zombie film I have ever seen (outside...
# 7                                               None
# 8  I'm not a big fan of South Korea movies or TV ...
# 9  This lively South Korean zombie flick arrives ...

# %%
def clean_review(string_list):
    '''
    Clean strings by removing punctuations, double spaces, uppercases (to lowercases)
    
        Args:
            string_list (a list of string): strings to be cleaned
        
        Return:
            cleaned_review (a list of string): cleaned version of all strings
    '''
    cleaned_review = []
    for review in string_list:
        cleaned_doc = re.sub(r"[^A-Za-z0-9 ]+", ' ', review)
        cleaned_doc = cleaned_doc.replace('  ', ' ')
        cleaned_doc = cleaned_doc.lower()
        cleaned_doc = cleaned_doc.strip()
        cleaned_review.append(cleaned_doc)
    return cleaned_review

review_df['Cleaned Review'] = clean_review(review_df['Review'])
review_df.head()
# Out:
#                                                Title Rating  \
# 0                                     Zombie Revival      8
# 1  Unforgettable experience! One of the best zomb...      9
# 2                   As Promised. Action-Packed Film!    NaN
# 3                      The Best Zombie Movie To Date     10
# 4                          best modern zombies movie     10
#
#                                               Review  \
# 0  Train to Busan was a treat. A look into Selfis...
# 1  Forget about the ordinary and immerse yourself...
# 2                                               None
# 3  This movie did what I have not seen many, if a...
# 4  Hello,We can argue whether a zombies should be...
#
#                                       Cleaned Review
# 0  train to busan was a treat a look into selfish...
# 1  forget about the ordinary and immerse yourself...
# 2                                               none
# 3  this movie did what i have not seen many if an...
# 4  hello we can argue whether a zombies should be...

# %%
useless_rows = review_df.loc[(review_df['Cleaned Review'] == 'none') | (review_df['Cleaned Review'] == '')].index
review_df.drop(useless_rows, inplace=True)
review_df.reset_index(drop=True, inplace=True)

# %%
bags_of_words = [TaggedDocument(doc.split(), [i]) for i, doc in enumerate(review_df['Cleaned Review'])]
model = Doc2Vec(vector_size=30, min_count=1, negative=10, workers=4)
model.build_vocab([x for x in bags_of_words])
model.train(bags_of_words, total_examples=len(bags_of_words), epochs=40)
model.wv.most_similar('zombies')
# Out:
# [('skinless', 0.6776388883590698),
#  ('uninfected', 0.645000159740448),
#  ('move', 0.6435787677764893),
#  ('disasters', 0.6255438327789307),
#  ('steroids', 0.6241950988769531),
#  ('damned', 0.6205729842185974),
#  ('fast', 0.618072509765625),
#  ('imagine', 0.6125448942184448),
#  ('quick', 0.6092504262924194),
#  ('monsters', 0.6080406904220581)]

# %%
def average_similarity(main_doc, doc_list):
    '''
    Find the average similarity of each review
        Args:
            main_doc: str
            doc_list: a list of strings
    
    This function is used to calculate the average of similarity between documents. 
    Using cosine similarity, it calculates the esimated vector distance between documents.
    After iterating through all docs in the list, the average is returned
    '''
    sim_array = [np.array([0])]
    # to avoid calculating similarity for itself 
    excluding_main_doc = [x for x in doc_list if x != main_doc]
    for doc in excluding_main_doc:
        sim_array = np.append(sim_array, model.wv.n_similarity(main_doc.split(), doc.split()))
    return sim_array.mean()


similarity_list = [average_similarity(doc, review_df['Cleaned Review']) for doc in review_df['Cleaned Review']]

# %%
review_df['Similarity'] = similarity_list
review_df.head(30)
# Out:
#                                                 Title Rating  \
# 0                                      Zombie Revival      8
# 1   Unforgettable experience! One of the best zomb...      9
# 2                       The Best Zombie Movie To Date     10
# 3                           best modern zombies movie     10
# 4                        More Than Just a Zombie Film     10
# 5              The best zombie movie I have ever seen     10
# 6                                    Worth your time!      9
# 7            Adds a lot of spark to the zombie genre.      8
# 8   Highly Entertaining - Climax after climax, not...      9
# 9                          An overall excellent movie     10
# 10           One of the best zombies film i ever seen     10
# 11                           First class all the way.      9
# 12  Challenge of Korean blockbuster, and it succee...      7
# 13                                  Great Thrill Ride      8
# 14                         Zombies on a train!? Boss!      7
# 15  Train to Busan: A contender for the greatest z...     10
# 16             One of the Best Zombie Films ever Made      8
# 17  Starts strong only to turn into a typical Holl...      6
# 18                 Powerful zombie movie with a heart      9
# 19                            Good action film but...      8
# 20                 Pretty good but not up to the hype      6
# 21  Simply put; An irrefutably all around exceptio...      9
# 22                  Starts well but runs out of steam      6
# 23                                          Thrilling      8
# 24  Not the best horror film of 2016, but it gets ...      6
# 25  Train to Busan an showed America how to make a...     10
# 26                             Emotional zombie movie      8
# 27                                Overall great movie      8
# 28            Breathing new life into a crowded genre      8
# 29  In a zombie apocalypse, the Koreans are just a...      5
#
#                                                Review  \
# 0   Train to Busan was a treat. A look into Selfis...
# 1   Forget about the ordinary and immerse yourself...
# 2   This movie did what I have not seen many, if a...
# 3   Hello,We can argue whether a zombies should be...
# 4   This new Korean film "Train to Busan" is certa...
# 5   The best zombie film I have ever seen (outside...
# 6   I'm not a big fan of South Korea movies or TV ...
# 7   This lively South Korean zombie flick arrives ...
# 8   If I have not watched the trailer, I will give...
# 9   A friend of mine recommended this movie. In hi...
# 10  Very good scenario and the actors are excellen...
# 11  Train To Busan can be summed up in four words:...
# 12  Making zombie blockbuster movies outside of Ho...
# 13  No genre has suffered from volume overload as ...
# 14  We're leaving (leaving) on that Zombie Train t...
# 15  There are rare events in our world, solar ecli...
# 16  The investment manager Seok Woo (Yoo Gong) is ...
# 17  Zombie movies aren't quite dead yet. Over the ...
# 18  South Korean cinema is so good. This movie is ...
# 19  Is this really a zombie film? I am not a genre...
# 20  I love horror movies, and this is on a lot of ...
# 21  With a dynamic storyline and multi-dimensional...
# 22  You may think you know all about zombies but h...
# 23  Intense and very enjoyable film. Love the acti...
# 24  This film had me at a crossroads; one the one ...
# 25  So, a typical Zombie movie from America has:\n...
# 26  This has to be one of the finest zombie and ho...
# 27  I don't normally watch foreign movies, but thi...
# 28  Train to Busan doesn't reinvent the wheel so m...
# 29  Would have been a lot better if the main chara...
#
#                                        Cleaned Review  Similarity
# 0   train to busan was a treat a look into selfish...    0.803121
# 1   forget about the ordinary and immerse yourself...    0.801100
# 2   this movie did what i have not seen many if an...    0.856433
# 3   hello we can argue whether a zombies should be...    0.826074
# 4   this new korean film train to busan is certain...    0.699606
# 5   the best zombie film i have ever seen outside ...    0.862866
# 6   i m not a big fan of south korea movies or tv ...    0.842687
# 7   this lively south korean zombie flick arrives ...    0.750722
# 8   if i have not watched the trailer i will give ...    0.853844
# 9   a friend of mine recommended this movie in his...    0.866699
# 10  very good scenario and the actors are excellen...    0.818509
# 11  train to busan can be summed up in four words ...    0.778561
# 12  making zombie blockbuster movies outside of ho...    0.859820
# 13  no genre has suffered from volume overload as ...    0.808032
# 14  we re leaving leaving on that zombie train to ...    0.831108
# 15  there are rare events in our world solar eclip...    0.837198
# 16  the investment manager seok woo yoo gong is a ...    0.631083
# 17  zombie movies aren t quite dead yet over the p...    0.863922
# 18  south korean cinema is so good this movie is p...    0.815736
# 19  is this really a zombie film i am not a genre ...    0.818777
# 20  i love horror movies and this is on a lot of p...    0.835030
# 21  with a dynamic storyline and multi dimensional...    0.859168
# 22  you may think you know all about zombies but h...    0.833114
# 23  intense and very enjoyable film love the actin...    0.720516
# 24  this film had me at a crossroads one the one s...    0.869586
# 25  so a typical zombie movie from america has a b...    0.783891
# 26  this has to be one of the finest zombie and ho...    0.835627
# 27  i don t normally watch foreign movies but this...    0.808187
# 28  train to busan doesn t reinvent the wheel so m...    0.753735
# 29  would have been a lot better if the main chara...    0.767970

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 8]

sns.distplot(review_df['Rating'], hist_kws={"rwidth":5,'edgecolor':'red'})
plt.xlim(-1, 11)
plt.xticks(range(11))
plt.ylabel('Density')
plt.title('Rating Distribution')
plt.show()

# %%
review_df['Rating'] = review_df['Rating'].apply(lambda x: int(x))
print('Average rating of Train to Busan is {}'.format(round(review_df['Rating'].mean(), 2)))
# Out:
# Average rating of Train to Busan is 8.32

# %% [raw]
# most mentioned words using Counter() & relation of rating to these words
